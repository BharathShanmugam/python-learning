# %%
import numpy as np
import pandas as pd
df=pd.read_csv("tips.csv")

# %%
df=pd.read_csv("tips.csv")

# %% [markdown]
# .APPLY()

# %%
def last_five(num):
    return str(num)[-5:]

# %%
last_five(123456789)
# Out:
# '56789'

# %% [markdown]
# Here the function we dont user () the pandas automaticaly execute the function

# %%
df["last_five CC"]=df["CC Number"].apply(last_five)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.5
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.4
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              11.8
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.2
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3               9.7
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              13.6
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.3
# 242       17.82  1.75    Male     No   Sat  Dinner     2               8.9
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.4
#
#              Payer Name         CC Number Payment ID last_five CC
# ...

# %%
df["price_per_person"]=np.round(df["price_per_person"],1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.5
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.4
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              11.8
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.2
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3               9.7
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              13.6
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.3
# 242       17.82  1.75    Male     No   Sat  Dinner     2               8.9
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.4
#
#              Payer Name         CC Number Payment ID last_five CC
# ...

# %%
df=pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# Multiple colums selections

# %%
df["total_bill"].apply(lambda bill: bill*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total,tip):
    if tip/total >0.25:
        return "Generous"
    else:
        return "Other"

# %%
df["Quality"]=np.vectorize(quality)(df["total_bill"],df["tip"])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Quality
# ...

# %%
df.sort_values(["tip","size"])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
# ...

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["sex"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["sex"].replace(["Female","Male"],["F","M"])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Quality
# ...

# %% [markdown]
# ***MAP***  in map function we have to first write a mapping dic and we have to use map function

# %%
mymap={"Female":"F","Male":"M"}

# %%
df["sex"].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated().count()
# Out:
# np.int64(244)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Quality
# ...

# %%
df.nlargest(2,"tip")
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID Quality
# 170    Gregory Clark  5473850968388236    Sat1954   Other
# 212  Alex Williamson      676218815212    Sat4590   Other

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 162       16.21  2.00  Female     No  Sun  Dinner     3              5.40
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2              5.04
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2              5.68
# 231       15.69  3.00    Male    Yes  Sat  Dinner     3              5.23
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
#
#          Payer Name         CC Number Payment ID Quality
# 162  Jennifer Baird  4227834176859693    Sun5521   Other
# 226      Ruth Weiss  5268689490381635    Fri6359   Other
# 100      Lori Lynch    38558279384492    Fri4106   Other
# 231     Jason Parks     4812333796161    Sat6334   Other
# 239   Michael Avila  5296068606052842    Sat2657   Other
